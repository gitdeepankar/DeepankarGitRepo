# %% [markdown]
# <a href="https://colab.research.google.com/github/gitdeepankar/DeepankarGitRepo/blob/main/ai-agents-demo/01_langchain-agent-weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -qU langchain langchain-google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.3/53.3 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.6/426.6 kB 24.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 32.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 16.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.43.0, but you have google-auth 2.45.0 which is incompatible.

# %%
# 2. Initialize the Gemini Model
# Use gemini-2.0-flash or gemini-1.5-pro
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

# %%
import os

api_key = os.environ.get("GOOGLE_API_KEY")

if api_key:
    print(f"GOOGLE_API_KEY is set. First 5 characters: {api_key[:5]}...")
else:
    print("GOOGLE_API_KEY is NOT set.")
# Out:
# GOOGLE_API_KEY is set. First 5 characters: AIzaS...

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents import create_agent
from langchain_core.tools import tool
from google.colab import userdata
# Ensure your API Key is set
os.environ["GOOGLE_API_KEY"] = userdata.get('GEMINI_API_KEY')

# %% [markdown]
# ### **Security Warning: Avoid hardcoding API keys directly in publicly shared notebooks.**
#
# If you must, set it as an environment variable like this:

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

# WARNING: Replace 'YOUR_API_KEY_HERE' with your actual API key.
# This method is not secure for shared notebooks.
os.environ["GOOGLE_API_KEY"] = "AIzaSyDVGpEcK9lIxAqqv_bAKIBTsr0alo7uExs"

# You can then initialize the model as usual:
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

print("Model initialized with API key set directly in code.")
# Out:
# Model initialized with API key set directly in code.

# %% [markdown]
# After executing this cell, the `llm` object will be initialized with the directly provided API key. For any shared work or production environment, always use Colab secrets or other secure methods to manage your API keys.

# %%
# 4. Run the agent
# Inputs follow the unified message list format
response = agent.invoke(
    {"messages": [("user", "What is the weather in New York?")]}
)

print(response["messages"][-1].content)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3039         try:
# -> 3040             response: GenerateContentResponse = self.client.models.generate_content(
#    3041                 **request,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5187         )
# -> 5188       return self._generate_content(
#    5189           model=model, contents=contents, config=parsed_config
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    3984
# -> 3985     response = self._api_client.request(
# ...

# %%
# 1. Define the Tool using the @tool decorator (2025 best practice)
@tool
def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"

# %%
# 2. Initialize the Gemini Model
# Use gemini-2.0-flash or gemini-1.5-pro
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

# %%
# 3. Create the Agent
# Note: create_agent replaces the deprecated create_react_agent helper
agent = create_agent(
    model=llm,
    tools=[get_weather],
    system_prompt="You are a helpful assistant"
)

# %%
# 4. Run the agent
# Inputs follow the unified message list format
response = agent.invoke(
    {"messages": [("user", "what is the weather in Dallas?")]}
)

print(response["messages"][-1].content)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3039         try:
# -> 3040             response: GenerateContentResponse = self.client.models.generate_content(
#    3041                 **request,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5187         )
# -> 5188       return self._generate_content(
#    5189           model=model, contents=contents, config=parsed_config
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    3984
# -> 3985     response = self._api_client.request(
# ...
